# %%
# -*- coding: utf-8 -*-
import matplotlib.pyplot as plt
plt.rc('font', family='NanumGothic')
plt.plot(['월','화','수','목'], [30,29,12,31])
plt.show()

# %%
import matplotlib.pyplot as plt
x=['mon','tue','wed','thu']
y=[30,29,12,31]
plt.plot(x,y)

plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_excel('./file/data2.xls')
plt.plot(df['name'],df['age'], color='red', label='나이', marker='*')
plt.title('우리반 연령별 성적표')
plt.plot(df['name'],df['score'], color='blue', label='점수', marker='o')
plt.legend()
plt.show()
